# %% [markdown]
# # ❓ Question Generation Demo
#
# This notebook demonstrates automatic question generation using NLP.

# %%
import sys
sys.path.append("../src")
from question_generator import generate_questions

# %%
text = """
Machine learning is a subset of artificial intelligence. It is widely used
in healthcare, education, and finance. Machine learning models learn from data
and make predictions automatically.
"""

# %%
questions = generate_questions(text)
for q in questions:
    print(q)
