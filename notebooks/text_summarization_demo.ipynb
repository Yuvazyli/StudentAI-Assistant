# %% [markdown]
# # 📄 Text Summarization Demo
#
# This notebook demonstrates ML-based text summarization using StudyBuddy-AI.

# %%
import sys
sys.path.append("../src")
from summarizer import summarize

# %%
text = """
Machine learning is a subset of artificial intelligence that focuses on
building systems that learn from data. It is widely used in healthcare,
education, finance, and many other domains. Machine learning models can
identify patterns and make predictions with minimal human intervention.
"""

# %%
summary = summarize(text)
print("Summary:\n")
print(summary)
